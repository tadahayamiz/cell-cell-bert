# %%
# ==============================
# PubMedBERT CPT (MLM only) + RAdam + loss logging
# + Validation Loss & Early Stopping
# ==============================
from transformers import (
    BertTokenizerFast,
    BertForMaskedLM,
    DataCollatorForLanguageModeling,
    Trainer,
    TrainingArguments,
    EarlyStoppingCallback,  # <--- 追加
)
from datasets import Dataset
import torch
import os
import pandas as pd
import itertools

# ---- パラメータ探索設定 ----
param_grid = {
    "learning_rate": [2e-05],
    "weight_decay": [0.0001],
    "warmup_ratio": [0.1],
}

# ---- 学習ループ ----
for lr, wd, warmup in itertools.product(
    param_grid["learning_rate"],
    param_grid["weight_decay"],
    param_grid["warmup_ratio"]
):

    # ---- トークナイザの準備 ----
    model_name = "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext"
    tokenizer = BertTokenizerFast.from_pretrained(model_name)
    tokenizer.add_special_tokens({'additional_special_tokens': ['<E1>', '</E1>', '<E0>', '</E0>']})

    cpt_path = "/workspace/250911_cells_knowledge_ext/01_semmed_to_pubmed/07_surround_entity/data/pubmed/surround_cell.csv"

    # --- データ読み込み ---
    cpt_df = pd.read_csv(cpt_path)

    tag_regex = r'</?E\d+>'
    indices_to_modify = cpt_df.sample(frac=0.5, random_state=42).index
    cpt_df.loc[indices_to_modify, 'Cleaned_Sentence'] = cpt_df.loc[indices_to_modify, 'Cleaned_Sentence'].str.replace(tag_regex, '', regex=True)

    print(cpt_df.head())

    dataset = Dataset.from_pandas(cpt_df)

    # --- トークナイズ ---
    def tokenize_function(examples):
        return tokenizer(
            examples["Cleaned_Sentence"],
            truncation=True,
            padding="max_length",
            max_length=128
        )

    tokenized_dataset_full = dataset.map(  # <--- 変更 (変数名)
        tokenize_function,
        batched=True,
        remove_columns=["pmid","sent_id","ID_A","ID_B","Selected_Term_A","Selected_Term_B","Cleaned_Sentence"]
    )

    # --- 検証用データセットの分割 (95% train, 5% eval) --- # <--- 追加
    split_dataset = tokenized_dataset_full.train_test_split(test_size=0.05, seed=42)
    train_dataset = split_dataset["train"]
    eval_dataset = split_dataset["test"]
    print(f"Train dataset size: {len(train_dataset)}, Eval dataset size: {len(eval_dataset)}")
    # --- ここまで追加 ---

    # ---- データコラトラ ----
    data_collator = DataCollatorForLanguageModeling(
        tokenizer=tokenizer,
        mlm=True,
        mlm_probability=0.15
    )

    exp_name = f"lr{lr}_wd{wd}_warmup{warmup}_half"
    output_dir = f"./surround_entity/{exp_name}"
    os.makedirs(output_dir, exist_ok=True)

    # ---- モデル読み込み ----
    model = BertForMaskedLM.from_pretrained(model_name)
    model.resize_token_embeddings(len(tokenizer))

    # ---- 早期停止コールバック ---- # <--- 追加
    early_stopping_callback = EarlyStoppingCallback(
        early_stopping_patience=5,  # 5回連続でeval_lossが改善しなかったら停止
        early_stopping_threshold=0.001 # 0.001未満の改善は「改善なし」とみなす
    )
    # --- ここまで追加 ---

    # ---- TrainingArguments ----
    training_args = TrainingArguments(
        output_dir=output_dir,
        overwrite_output_dir=True,
        num_train_epochs=2,                 # 早期停止するため、ここは最大エポック数を指定
        per_device_train_batch_size=128,
        gradient_accumulation_steps=4,
        learning_rate=lr,
        weight_decay=wd,
        warmup_ratio=warmup,
        lr_scheduler_type="linear",
        
        logging_steps=200,                  # 200ステップごとにログ記録
        eval_strategy="steps",        # <--- 追加: ステップごとに評価
        eval_steps=200,                     # <--- 追加: 200ステップごとに評価（logging_stepsと合わせる）
        save_strategy="steps",              # <--- 変更: ステップごとに保存（評価と合わせる）
        save_steps=200,                     # <--- 変更: 200ステップごとに保存
        
        load_best_model_at_end=True,        # <--- 追加: 学習終了時に最良モデルをロード
        metric_for_best_model="eval_loss",  # <--- 追加: 最良モデルの指標はeval_loss
        greater_is_better=False,            # <--- 追加: lossは低い方が良い
        save_total_limit=2,                 # チェックポイントは2つまで
        
        dataloader_num_workers=8,
        fp16=True,
        report_to="none",
        optim="schedule_free_radam",
        logging_dir=f"{output_dir}/logs",
        log_level="info",
    )

    # ---- Trainer ----
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,   # <--- 変更: 訓練用データ
        eval_dataset=eval_dataset,     # <--- 追加: 検証用データを追加
        data_collator=data_collator,
        callbacks=[early_stopping_callback] # <--- 追加: 早期停止コールバック
    )

    # ---- 学習 ----
    print(f"\n=== Training {exp_name} ===")
    train_result = trainer.train()
    
    # ---- 最終メトリクス保存 ---- # <--- 変更
    metrics = train_result.metrics
    metrics["final_step"] = trainer.state.global_step # 早期停止した場合のステップ数を記録
    pd.DataFrame([metrics]).to_csv(f"{output_dir}/final_training_metrics.csv", index=False)

    # ---- ステップごとの全ログ履歴を保存 ---- # <--- 追加
    log_history_df = pd.DataFrame(trainer.state.log_history)
    log_history_df.to_csv(f"{output_dir}/full_log_history.csv", index=False)

    # ---- 保存 ----
    # load_best_model_at_end=True のため、trainer.modelは既に検証ロス最小のモデル
    trainer.save_model(output_dir)
    tokenizer.save_pretrained(output_dir)
    print(f"Saved best model (based on eval_loss) and tokenizer to {output_dir}") # <--- 変更
# Out:
#    pmid  sent_id        ID_A        ID_B Selected_Term_A Selected_Term_B  \
# 0    22       13  CL:0000738  CL:0000542       leucocyte      lymphocyte
# 1    92      611  CL:0000738  CL:0000232       leucocyte     erythrocyte
# 2    92      612  CL:0000738  CL:0000232       leucocyte     erythrocyte
# 3   325     1212  CL:0000236  CL:0000084          B-cell          T cell
# 4   325     1213  CL:0000235  CL:0000236      macrophage          B cell
#
#                                     Cleaned_Sentence
# 0  Finally, the total amount of leucocytes and ly...
# 1  An alkaline protease (pH 7.4) with properties ...
# 2  The similarity between the properties of the l...
# 3  The delayed transfer of GVH cells to irradiate...
# 4  Supplementation of <E0>macrophage</E0>-deplete...
# Map: 100%|██████████| 2121113/2121113 [04:30<00:00, 7834.89 examples/s]
# Train dataset size: 2015057, Eval dataset size: 106056
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Using auto half precision backend
# ***** Running training *****
#   Num examples = 2,015,057
#   Num Epochs = 2
#   Instantaneous batch size per device = 128
#   Total train batch size (w. parallel, distributed & accumulation) = 512
#   Gradient Accumulation steps = 4
#   Total optimization steps = 7,872
#   Number of trainable parameters = 109,517,374
# === Training lr2e-05_wd0.0001_warmup0.1_half ===
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#     <div>
#
#       <progress value='7872' max='7872' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7872/7872 5:00:07, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>1.474800</td>
#       <td>1.300674</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.327500</td>
#       <td>1.209603</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.263100</td>
#       <td>1.166385</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.235400</td>
#       <td>1.150335</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.221500</td>
#       <td>1.138418</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.208200</td>
#       <td>1.133362</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>1.205700</td>
#       <td>1.121078</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>1.196800</td>
#       <td>1.120968</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>1.188900</td>
#       <td>1.113185</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.187100</td>
#       <td>1.107955</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>1.190900</td>
#       <td>1.108829</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>1.184900</td>
#       <td>1.104772</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>1.180100</td>
#       <td>1.103324</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>1.179500</td>
#       <td>1.097938</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.174600</td>
#       <td>1.102291</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>1.168800</td>
#       <td>1.099945</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>1.170500</td>
#       <td>1.096623</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>1.164200</td>
#       <td>1.093038</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>1.164300</td>
#       <td>1.097168</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.159000</td>
#       <td>1.090950</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>1.157200</td>
#       <td>1.087160</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>1.162100</td>
#       <td>1.085331</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>1.158200</td>
#       <td>1.087098</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>1.155300</td>
#       <td>1.088572</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.157400</td>
#       <td>1.082931</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>1.155600</td>
#       <td>1.080214</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>1.153800</td>
#       <td>1.083850</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>1.151900</td>
#       <td>1.083546</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>1.148300</td>
#       <td>1.074757</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.148700</td>
#       <td>1.076099</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>1.146200</td>
#       <td>1.077621</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>1.145300</td>
#       <td>1.077124</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>1.143400</td>
#       <td>1.078606</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>1.146000</td>
#       <td>1.073526</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>1.141800</td>
#       <td>1.074224</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>1.140900</td>
#       <td>1.068638</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>1.138100</td>
#       <td>1.072161</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>1.140800</td>
#       <td>1.073651</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>1.142000</td>
#       <td>1.073272</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-200
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-200/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-200/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-200/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-400
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-400/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-400/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-400/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-400/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-600
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-600/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-600/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-600/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-600/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-200] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-800
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-800/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-800/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-800/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-800/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-400] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1000
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1000/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1000/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1000/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-600] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1200
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1200/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1200/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1200/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1200/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-800] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1400
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1400/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1400/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1400/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1400/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1600
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1600/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1600/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1600/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1600/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1200] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1800
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1800/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1800/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1800/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1800/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1400] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2000
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2000/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2000/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2000/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1600] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2200
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2200/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2200/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-2200/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-1800] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# ...
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7200
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7200/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7200/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7200/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7200/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-6800] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7400
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7400/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7400/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7400/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7400/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7600
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7600/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7600/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7600/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7600/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7400] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 106056
#   Batch size = 8
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7800
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7800/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7800/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7800/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7800/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7600] due to args.save_total_limit
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7872
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7872/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7872/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7872/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7872/special_tokens_map.json
# Deleting older checkpoint [surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7800] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/checkpoint-7200 (score: 1.0686383247375488).
# There were missing keys in the checkpoint model loaded: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias'].
# Saving model checkpoint to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half
# Configuration saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/config.json
# Model weights saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/model.safetensors
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/special_tokens_map.json
# tokenizer config file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/tokenizer_config.json
# Special tokens file saved in ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half/special_tokens_map.json
# Saved best model (based on eval_loss) and tokenizer to ./surround_entity/lr2e-05_wd0.0001_warmup0.1_half
